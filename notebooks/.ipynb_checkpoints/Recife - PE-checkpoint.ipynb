# %% [markdown]
# In this analysis, it was used the data made available by the **Infodengue** (https://info.dengue.mat.br/) . It was used the data until the end of the 2021 year for the Recife city.
#
# The data is saved in the data folder. It was named as: `{disease}_{ibge_code}.csv` and assigned with `cluster` in the end when it refers to the clustered data.
#
# Let's look at the dengue and chik data for this case. Note that we have some statistics related to humidity, temperature, and the number of cases. These features will be used to forecast the number of dengue cases reported.

# %%
import sys
import pickle
sys.path.append('..')
import pandas as pd
from datetime import datetime
from pgbm_model import qf_prediction
import matplotlib.pyplot as plt
from lstm import transf_chik_pred
from lstm import apply_dengue_chik
from preprocessing import get_nn_data
from lstm import build_model, make_pred
from pgbm_model import  cross_dengue_chik_prediction
from sklearn.metrics import mean_squared_error as mse

# %%
CITY = 2611606
CITY_NAME = 'Recife'
STATE = 'PE'
END_DATE = '2021-01-01' # assign the last day used to train the dengue model
INI_DATE_CHIK = '2021-01-01' # assign the first day used to retrain the model with chik data 
END_TRAIN_CHIK = '2021-05-01' # assign the last day used to retrain the model with chik data
END_DATE_CHIK = '2022-01-01' # assign the last day of chik data used to apply the trained model 
INI_EVALUATE = '2021-05-02' # assign the first day used to evaluate the trained model (transfer learning)
END_EVALUATE = '2021-06-06' # assign the last day used to evaluate the trained model (transfer learning)
PREDICT_N = 4
LOOK_BACK = 4

# %%
df_dengue = pd.read_csv(f'../data/dengue_{CITY}.csv', index_col = 'Unnamed: 0' )
df_dengue.index = pd.to_datetime(df_dengue.index)
df_dengue
# Out:
#             casos_2611606  casos_est_2611606  casos_est_min_2611606  \
# 2010-01-03              3                3.0                      3
# 2010-01-10              1                1.0                      1
# 2010-01-17              2                2.0                      2
# 2010-01-24              1                1.0                      1
# 2010-01-31              0                0.0                      0
# ...                   ...                ...                    ...
# 2022-05-29             71               95.0                     77
# 2022-06-05             75              105.0                     83
# 2022-06-12             41               82.0                     53
# 2022-06-19             35               91.0                     49
# 2022-06-26             24              104.0                     43
#
#             casos_est_max_2611606  p_rt1_2611606  p_inc100k_2611606  \
# 2010-01-03                      3       0.000000           0.181438
# 2010-01-10                      1       0.000000           0.060479
# 2010-01-17                      2       0.000000           0.120958
# 2010-01-24                      1       0.000000           0.060479
# 2010-01-31                      0       0.000000           0.000000
# ...                           ...            ...                ...
# 2022-05-29                    134       0.468386           5.745524
# 2022-06-05                    154       0.768051           6.350316
# 2022-06-12                    160       0.149694           4.959294
# 2022-06-19                    204       0.382086           5.503607
# 2022-06-26                    386       0.818693           6.289837
#
#             temp_min_2611606  temp_max_2611606  umid_min_2611606  \
# 2010-01-03         25.000000         29.666667         56.666667
# 2010-01-10         25.000000         29.428571         59.142857
# 2010-01-17         25.000000         29.142857         63.000000
# 2010-01-24         24.142857         29.000000         67.000000
# 2010-01-31         24.857143         30.000000         56.714286
# ...                      ...               ...               ...
# 2022-05-29         23.000000         27.428571         77.831345
# 2022-06-05         23.571429         28.000000         77.063711
# 2022-06-12         23.000000         26.857143         77.824348
# 2022-06-19         23.285714         28.428571         66.299810
# 2022-06-26         22.714286         27.714286         68.303886
#
#             pressao_min_2611606
# 2010-01-03          1009.666667
# 2010-01-10          1010.142857
# 2010-01-17          1011.571429
# 2010-01-24          1010.714286
# 2010-01-31          1009.142857
# ...                         ...
# 2022-05-29          1012.571429
# 2022-06-05          1010.714286
# 2022-06-12          1012.000000
# 2022-06-19          1013.142857
# 2022-06-26          1012.571429
#
# [651 rows x 10 columns]

# %% [markdown]
# Note that the chik dataset has the same columns

# %%
df_chik = pd.read_csv(f'../data/chik_{CITY}.csv', index_col = 'Unnamed: 0' )
df_chik.index = pd.to_datetime(df_chik.index)
df_chik
# Out:
#             casos_2611606  casos_est_2611606  casos_est_min_2611606  \
# 2010-01-03              0                0.0                      0
# 2010-01-10              0                0.0                      0
# 2010-01-17              0                0.0                      0
# 2010-01-24              0                0.0                      0
# 2010-01-31              0                0.0                      0
# ...                   ...                ...                    ...
# 2022-05-29             41               54.5                     44
# 2022-06-05             27               44.0                     31
# 2022-06-12             18               38.0                     22
# 2022-06-19             15               41.0                     20
# 2022-06-26              6               37.0                     13
#
#             casos_est_max_2611606  p_rt1_2611606  p_inc100k_2611606  \
# 2010-01-03                    0.0       0.000000           0.000000
# 2010-01-10                    0.0       0.000000           0.000000
# 2010-01-17                    0.0       0.000000           0.000000
# 2010-01-24                    0.0       0.000000           0.000000
# 2010-01-31                    0.0       0.000000           0.000000
# ...                           ...            ...                ...
# 2022-05-29                   53.0       0.427148           3.296116
# 2022-06-05                   53.0       0.300840           2.661085
# 2022-06-12                   53.0       0.144230           2.298210
# 2022-06-19                   53.0       0.344311           2.479647
# 2022-06-26                   53.0       0.329827           2.237731
#
#             temp_min_2611606  temp_max_2611606  umid_min_2611606  \
# 2010-01-03         25.000000         29.666667         56.666667
# 2010-01-10         25.000000         29.428571         59.142857
# 2010-01-17         25.000000         29.142857         63.000000
# 2010-01-24         24.142857         29.000000         67.000000
# 2010-01-31         24.857143         30.000000         56.714286
# ...                      ...               ...               ...
# 2022-05-29         23.000000         27.428571         77.831345
# 2022-06-05         23.571429         28.000000         77.063711
# 2022-06-12         23.000000         26.857143         77.824348
# 2022-06-19         23.285714         28.428571         66.299810
# 2022-06-26         22.714286         27.714286         68.303886
#
#             pressao_min_2611606
# 2010-01-03          1009.666667
# 2010-01-10          1010.142857
# 2010-01-17          1011.571429
# 2010-01-24          1010.714286
# 2010-01-31          1009.142857
# ...                         ...
# 2022-05-29          1012.571429
# 2022-06-05          1010.714286
# 2022-06-12          1012.000000
# 2022-06-19          1013.142857
# 2022-06-26          1012.571429
#
# [651 rows x 10 columns]

# %% [markdown]
# The main difference between the datasets above and the datasets with names ended with `cluster` is the number of columns. This dataset has columns with data from other cities. The city is identified by a 7-number code. These cities was clusterized with Recife (in this case) using a hierarchical clusterization algorithm.

# %%
df_chik_cluster = pd.read_csv(f'../data/chik_{CITY}_cluster.csv', index_col = 'Unnamed: 0' )
df_chik_cluster.index = pd.to_datetime(df_chik_cluster.index)
df_chik_cluster
# Out:
# 2022-06-05           0.000000         20.857143         26.142857
# 2022-06-12           5.529444         20.000000         24.714286
# 2022-06-19           0.000000         20.000000         26.000000
# 2022-06-26           5.529444         19.000000         25.714286
#
#             umid_min_2613800  pressao_min_2613800
# 2010-01-03         48.000000          1010.666667
# 2010-01-10         46.571429          1011.000000
# 2010-01-17         46.857143          1012.714286
# 2010-01-24         48.142857          1011.571429
# 2010-01-31         49.000000          1010.000000
# ...                      ...                  ...
# 2022-05-29         76.269180          1015.000000
# 2022-06-05         74.331669          1013.000000
# 2022-06-12         76.677290          1014.142857
# 2022-06-19         71.428282          1015.428571
# 2022-06-26         70.025968          1013.000000
#
# [651 rows x 130 columns]

# %% [markdown]
# We need to have this kind of data because, in our tests, the gradient boosting tree model perform betters when using the cluster data, while the neural network model performed better using only the city's data.

# %% [markdown]
# Let's plot this two incidence curver (dengue and chik):

# %%
fig, ax = plt.subplots()

ax.plot(df_dengue[f'casos_est_{CITY}'], label = 'dengue')

ax.plot(df_chik[f'casos_est_{CITY}'], label = 'chik')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Neural network model (NN)
#
# First, we make the prediction using the data up to 2021-01-01 and use 25% data to test the model. It used 25% of the training data as validation data. It used the early stop config to train the model faster to monitor the loss function.
#
# Before applying the nn model we compute the first derivative of our target (the incidence curve) and added it as a feature.
#
# The neural newtork model is constructed using the `build_model` function. This function create a model with a bidirectional LSTM layer and a simple LSTM layer. We use the last 4 (look_back parameter) observations to predict the next 4 (predict_n parameter).

# %% [markdown]
# The predictions of this models are saved in the path:
# './predictions/lstm/lstm_{city}_dengue_{label}.pkl'
#
# The model is saved in the path:
# './saved_models/lstm/trained_{geocode}_model_{label}.h5'

# %%
# %%time

model = build_model(hidden = 8, features = 11, predict_n = PREDICT_N, look_back=LOOK_BACK, batch_size=1, loss = 'msle')

make_pred(model, CITY, doenca = 'dengue', epochs = 100, end_train_date = None, 
                ratio= 0.75, end_date = END_DATE, hidden = 8,
                 predict_n = PREDICT_N, look_back =  LOOK_BACK, label = 'msle')
# Out:
# 2022-08-31 12:49:07.626096: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-31 12:49:07.627492: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# Compilation Time :  0.03188514709472656
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4, 11)]           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 4, 8)              1280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 8)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 36
# =================================================================
# Total params: 1,860
# Trainable params: 1,860
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 318 samples, validate on 107 samples
# Epoch 1/100
#   2/318 [..............................] - ETA: 11:28 - loss: 8.0430e-04 - accuracy: 0.5000 - mape: 1274726.6250 - mse: 8.3796e-04
# 2022-08-31 12:49:12.752125: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.
# 318/318 [==============================] - 9s 29ms/sample - loss: 0.0212 - accuracy: 0.2610 - mape: 10621368.0000 - mse: 0.0376 - val_loss: 0.0063 - val_accuracy: 0.3084 - val_mape: 409.3035 - val_mse: 0.0073
# Epoch 2/100
# 318/318 [==============================] - 4s 13ms/sample - loss: 0.0068 - accuracy: 0.2484 - mape: 4693995.5000 - mse: 0.0137 - val_loss: 0.0011 - val_accuracy: 0.2056 - val_mape: 104.9942 - val_mse: 0.0014
# Epoch 3/100
# 318/318 [==============================] - 25s 80ms/sample - loss: 0.0045 - accuracy: 0.3176 - mape: 1570839.0000 - mse: 0.0093 - val_loss: 6.0331e-04 - val_accuracy: 0.2150 - val_mape: 88.2518 - val_mse: 6.9693e-04
# Epoch 27/100
# 318/318 [==============================] - 24s 74ms/sample - loss: 0.0044 - accuracy: 0.3208 - mape: 2692512.5000 - mse: 0.0089 - val_loss: 7.8457e-04 - val_accuracy: 0.1682 - val_mape: 82.7453 - val_mse: 9.7754e-04
# Epoch 28/100
# 318/318 [==============================] - 25s 77ms/sample - loss: 0.0044 - accuracy: 0.3365 - mape: 1920140.5000 - mse: 0.0087 - val_loss: 7.2774e-04 - val_accuracy: 0.2336 - val_mape: 82.3280 - val_mse: 8.6708e-04
# Epoch 29/100
# 318/318 [==============================] - 29s 92ms/sample - loss: 0.0042 - accuracy: 0.3365 - mape: 1755499.1250 - mse: 0.0084 - val_loss: 6.3438e-04 - val_accuracy: 0.2523 - val_mape: 83.9386 - val_mse: 7.2262e-04
# CPU times: user 20min 7s, sys: 1min 31s, total: 21min 38s
# Wall time: 15min 41s
#                                     0            1             2             3
# mean_absolute_error         38.498656    43.131529     53.095797     67.996372
# explained_variance_score     0.931374     0.895606      0.838661      0.756258
# mean_squared_error        6697.629468  9838.599709  15222.917104  22653.537791
# mean_squared_log_error       0.688048     0.386169      0.362276      0.641599
# median_absolute_error       18.487275    17.716255     18.955914     24.179554
# r2_score                     0.927697     0.893770      0.835617      0.755358

# %% [markdown]
# ### PGBM model (ml)
#
# In this case, we use the last 4 observations to predict the next 4. Since a GBT (gradient boosting tree) model has a 1D target, we trained four different models each one specialized in predicting one of the next four observations.
#
# The predictions are saved in the path: './predictions/pgbm/pgbm_{city}_{doenca}_predictions.pkl'
#
# The models are saved in the path:
# './saved_models/pgbm/{city}_{doenca}_city_model_{d}_pgbm.pt'
# where d is in the arange 1 to 4.

# %%
# %%time

preds, preds25, preds975, X_train, targets = qf_prediction(CITY, STATE, predict_n = PREDICT_N, look_back = LOOK_BACK,
                                                           doenca = 'dengue', ratio = 0.75, ini_date = None,
                                                           end_date = END_DATE)
# Out:
# /opt/anaconda3/envs/alerta_dengue/lib/python3.7/site-packages/numba/np/ufunc/parallel.py:365: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 10005. The TBB threading layer is disabled.
#   warnings.warn(problem)
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Estimator 0/100, Train metric: 313.2034
# Estimator 1/100, Train metric: 285.8959
# Estimator 2/100, Train metric: 261.2120
# Estimator 3/100, Train metric: 238.7032
# Estimator 4/100, Train metric: 218.4290
# Estimator 5/100, Train metric: 200.0597
# Estimator 6/100, Train metric: 183.3380
# Estimator 7/100, Train metric: 168.1003
# Estimator 8/100, Train metric: 154.0578
# Estimator 9/100, Train metric: 141.3489
# Estimator 10/100, Train metric: 129.8515
# Estimator 11/100, Train metric: 119.2536
# Estimator 12/100, Train metric: 109.5979
# Estimator 13/100, Train metric: 100.7646
# Estimator 14/100, Train metric: 92.6602
# Estimator 15/100, Train metric: 85.2916
# Estimator 16/100, Train metric: 78.5319
# Estimator 17/100, Train metric: 72.4479
# Estimator 18/100, Train metric: 66.6340
# Estimator 19/100, Train metric: 61.5469
# Estimator 20/100, Train metric: 56.6950
# Estimator 21/100, Train metric: 52.3619
# Estimator 22/100, Train metric: 48.4259
# Estimator 23/100, Train metric: 44.8905
# Estimator 24/100, Train metric: 41.6281
# Estimator 25/100, Train metric: 38.6731
# Estimator 26/100, Train metric: 35.9854
# Estimator 27/100, Train metric: 33.5646
# Estimator 28/100, Train metric: 31.1201
# Estimator 29/100, Train metric: 28.9055
# Estimator 30/100, Train metric: 26.8595
# Estimator 31/100, Train metric: 25.1451
# Estimator 32/100, Train metric: 23.5988
# Estimator 33/100, Train metric: 21.9488
# Estimator 34/100, Train metric: 20.4412
# Estimator 35/100, Train metric: 19.0699
# Estimator 36/100, Train metric: 17.8168
# Estimator 37/100, Train metric: 16.6558
# Estimator 38/100, Train metric: 15.6076
# Estimator 39/100, Train metric: 14.6716
# Estimator 40/100, Train metric: 13.7927
# Estimator 41/100, Train metric: 13.0010
# Estimator 42/100, Train metric: 12.3652
# Estimator 43/100, Train metric: 11.6968
# Estimator 44/100, Train metric: 11.0390
# Estimator 45/100, Train metric: 10.4312
# Estimator 46/100, Train metric: 9.8911
# Estimator 47/100, Train metric: 9.4064
# Estimator 48/100, Train metric: 8.9374
# Estimator 49/100, Train metric: 8.4981
# Estimator 50/100, Train metric: 8.1034
# Estimator 51/100, Train metric: 7.7410
# Estimator 52/100, Train metric: 7.4269
# Estimator 53/100, Train metric: 7.1258
# Estimator 54/100, Train metric: 6.8249
# Estimator 55/100, Train metric: 6.5889
# Estimator 56/100, Train metric: 6.3426
# Estimator 57/100, Train metric: 6.1317
# Estimator 58/100, Train metric: 5.9471
# Estimator 59/100, Train metric: 5.7280
# Estimator 60/100, Train metric: 5.5695
# Estimator 61/100, Train metric: 5.4007
# Estimator 62/100, Train metric: 5.2438
# Estimator 63/100, Train metric: 5.0578
# Estimator 64/100, Train metric: 4.9262
# Estimator 65/100, Train metric: 4.7751
# Estimator 66/100, Train metric: 4.6681
# Estimator 67/100, Train metric: 4.5419
# Estimator 68/100, Train metric: 4.4484
# Estimator 69/100, Train metric: 4.3152
# Estimator 70/100, Train metric: 4.2091
# Estimator 71/100, Train metric: 4.1185
# Estimator 72/100, Train metric: 4.0190
# Estimator 73/100, Train metric: 3.9125
# Estimator 74/100, Train metric: 3.8205
# Estimator 75/100, Train metric: 3.7180
# Estimator 76/100, Train metric: 3.6236
# Estimator 77/100, Train metric: 3.5419
# Estimator 78/100, Train metric: 3.4262
# Estimator 79/100, Train metric: 3.3461
# Estimator 80/100, Train metric: 3.2633
# Estimator 81/100, Train metric: 3.1889
# Estimator 82/100, Train metric: 3.1144
# Estimator 83/100, Train metric: 3.0354
# Estimator 84/100, Train metric: 2.9598
# Estimator 85/100, Train metric: 2.8891
# Estimator 86/100, Train metric: 2.8198
# Estimator 87/100, Train metric: 2.7325
# Estimator 88/100, Train metric: 2.6657
# Estimator 89/100, Train metric: 2.5944
# Estimator 90/100, Train metric: 2.5387
# Estimator 91/100, Train metric: 2.4777
# Estimator 92/100, Train metric: 2.4294
# Estimator 93/100, Train metric: 2.3819
# Estimator 94/100, Train metric: 2.3185
# Estimator 95/100, Train metric: 2.2742
# Estimator 96/100, Train metric: 2.2292
# Estimator 97/100, Train metric: 2.1744
# Estimator 98/100, Train metric: 2.1319
# Estimator 99/100, Train metric: 2.0925
# Estimator 0/100, Train metric: 313.5782
# Estimator 1/100, Train metric: 286.5708
# Estimator 2/100, Train metric: 262.0909
# Estimator 3/100, Train metric: 239.9887
# Estimator 4/100, Train metric: 219.7106
# Estimator 5/100, Train metric: 201.4884
# Estimator 6/100, Train metric: 184.9513
# Estimator 7/100, Train metric: 169.5379
# Estimator 8/100, Train metric: 155.6103
# Estimator 9/100, Train metric: 143.0255
# Estimator 10/100, Train metric: 131.4606
# Estimator 11/100, Train metric: 120.9689
# Estimator 12/100, Train metric: 111.4220
# Estimator 13/100, Train metric: 102.4628
# Estimator 14/100, Train metric: 94.5244
# Estimator 15/100, Train metric: 87.1815
# Estimator 16/100, Train metric: 80.5178
# Estimator 17/100, Train metric: 74.4754
# Estimator 18/100, Train metric: 69.1011
# Estimator 19/100, Train metric: 64.1541
# Estimator 20/100, Train metric: 59.1829
# Estimator 21/100, Train metric: 54.7065
# Estimator 22/100, Train metric: 50.6286
# Estimator 23/100, Train metric: 46.8979
# Estimator 24/100, Train metric: 43.5559
# Estimator 25/100, Train metric: 40.6127
# Estimator 26/100, Train metric: 37.7531
# Estimator 27/100, Train metric: 35.1996
# Estimator 28/100, Train metric: 32.8848
# Estimator 29/100, Train metric: 30.7977
# Estimator 30/100, Train metric: 28.6537
# Estimator 31/100, Train metric: 26.6729
# Estimator 32/100, Train metric: 24.9351
# Estimator 33/100, Train metric: 23.2689
# Estimator 34/100, Train metric: 21.7747
# Estimator 35/100, Train metric: 20.3726
# Estimator 36/100, Train metric: 19.1049
# Estimator 37/100, Train metric: 17.9676
# Estimator 38/100, Train metric: 16.9259
# Estimator 39/100, Train metric: 15.9734
# Estimator 40/100, Train metric: 15.0569
# Estimator 41/100, Train metric: 14.2354
# Estimator 42/100, Train metric: 13.5003
# Estimator 43/100, Train metric: 12.8448
# Estimator 44/100, Train metric: 12.2450
# Estimator 45/100, Train metric: 11.6466
# Estimator 46/100, Train metric: 11.1558
# Estimator 47/100, Train metric: 10.6255
# Estimator 48/100, Train metric: 10.2032
# Estimator 49/100, Train metric: 9.8313
# Estimator 50/100, Train metric: 9.4807
# Estimator 51/100, Train metric: 9.1768
# Estimator 52/100, Train metric: 8.8728
# Estimator 53/100, Train metric: 8.5556
# Estimator 54/100, Train metric: 8.2807
# Estimator 55/100, Train metric: 8.0247
# Estimator 56/100, Train metric: 7.7896
# Estimator 57/100, Train metric: 7.5612
# Estimator 58/100, Train metric: 7.3428
# Estimator 59/100, Train metric: 7.1470
# Estimator 60/100, Train metric: 6.9355
# Estimator 61/100, Train metric: 6.7478
# Estimator 62/100, Train metric: 6.5671
# Estimator 63/100, Train metric: 6.4045
# Estimator 64/100, Train metric: 6.2364
# Estimator 65/100, Train metric: 6.0874
# Estimator 66/100, Train metric: 5.9407
# Estimator 67/100, Train metric: 5.8073
# Estimator 68/100, Train metric: 5.6601
# Estimator 69/100, Train metric: 5.5082
# Estimator 70/100, Train metric: 5.3730
# Estimator 71/100, Train metric: 5.2415
# Estimator 72/100, Train metric: 5.1178
# Estimator 73/100, Train metric: 5.0145
# Estimator 74/100, Train metric: 4.8914
# Estimator 75/100, Train metric: 4.7803
# Estimator 76/100, Train metric: 4.6738
# Estimator 77/100, Train metric: 4.5670
# Estimator 78/100, Train metric: 4.4778
# Estimator 79/100, Train metric: 4.3536
# Estimator 80/100, Train metric: 4.2644
# Estimator 81/100, Train metric: 4.1834
# Estimator 82/100, Train metric: 4.1004
# Estimator 83/100, Train metric: 4.0124
# Estimator 84/100, Train metric: 3.9279
# Estimator 85/100, Train metric: 3.8441
# Estimator 86/100, Train metric: 3.7718
# Estimator 87/100, Train metric: 3.6696
# Estimator 88/100, Train metric: 3.5945
# Estimator 89/100, Train metric: 3.5195
# Estimator 90/100, Train metric: 3.4530
# Estimator 91/100, Train metric: 3.3780
# Estimator 92/100, Train metric: 3.3189
# Estimator 93/100, Train metric: 3.2588
# Estimator 94/100, Train metric: 3.1958
# Estimator 95/100, Train metric: 3.1328
# Estimator 96/100, Train metric: 3.0435
# Estimator 97/100, Train metric: 2.9891
# Estimator 98/100, Train metric: 2.9316
# Estimator 99/100, Train metric: 2.8726
# Estimator 0/100, Train metric: 314.0910
# Estimator 1/100, Train metric: 287.6887
# Estimator 2/100, Train metric: 263.7912
# Estimator 3/100, Train metric: 242.2150
# Estimator 4/100, Train metric: 222.4051
# Estimator 5/100, Train metric: 204.3417
# Estimator 6/100, Train metric: 188.1462
# Estimator 7/100, Train metric: 172.9916
# Estimator 8/100, Train metric: 159.2866
# Estimator 9/100, Train metric: 146.8935
# Estimator 10/100, Train metric: 135.5793
# Estimator 11/100, Train metric: 125.0652
# Estimator 12/100, Train metric: 115.8529
# Estimator 13/100, Train metric: 107.5313
# Estimator 14/100, Train metric: 99.6325
# Estimator 15/100, Train metric: 91.9431
# Estimator 16/100, Train metric: 84.9567
# Estimator 17/100, Train metric: 78.8059
# Estimator 18/100, Train metric: 72.9519
# Estimator 19/100, Train metric: 67.9093
# Estimator 20/100, Train metric: 63.0816
# Estimator 21/100, Train metric: 58.7490
# Estimator 22/100, Train metric: 54.8154
# Estimator 23/100, Train metric: 51.2621
# Estimator 24/100, Train metric: 47.7528
# Estimator 25/100, Train metric: 44.5764
# Estimator 26/100, Train metric: 41.8905
# Estimator 27/100, Train metric: 39.2444
# Estimator 28/100, Train metric: 36.8518
# Estimator 29/100, Train metric: 34.5460
# Estimator 30/100, Train metric: 32.4478
# Estimator 31/100, Train metric: 30.5769
# Estimator 32/100, Train metric: 28.6936
# Estimator 33/100, Train metric: 27.1500
# Estimator 34/100, Train metric: 25.7610
# Estimator 35/100, Train metric: 24.5248
# Estimator 36/100, Train metric: 23.4278
# Estimator 37/100, Train metric: 22.4142
# Estimator 38/100, Train metric: 21.3143
# Estimator 39/100, Train metric: 20.4262
# Estimator 40/100, Train metric: 19.6933
# Estimator 41/100, Train metric: 18.9329
# Estimator 42/100, Train metric: 18.2375
# Estimator 43/100, Train metric: 17.5819
# Estimator 44/100, Train metric: 16.9891
# Estimator 45/100, Train metric: 16.4620
# Estimator 46/100, Train metric: 15.9367
# Estimator 47/100, Train metric: 15.4063
# Estimator 48/100, Train metric: 14.9360
# Estimator 49/100, Train metric: 14.4977
# Estimator 50/100, Train metric: 14.1025
# Estimator 51/100, Train metric: 13.6902
# Estimator 52/100, Train metric: 13.3164
# Estimator 53/100, Train metric: 12.9378
# Estimator 54/100, Train metric: 12.6191
# Estimator 55/100, Train metric: 12.2810
# Estimator 56/100, Train metric: 11.9558
# Estimator 57/100, Train metric: 11.6523
# Estimator 58/100, Train metric: 11.3683
# Estimator 59/100, Train metric: 11.1259
# Estimator 60/100, Train metric: 10.8634
# Estimator 61/100, Train metric: 10.6010
# Estimator 62/100, Train metric: 10.3505
# Estimator 63/100, Train metric: 10.1364
# Estimator 64/100, Train metric: 9.9241
# Estimator 65/100, Train metric: 9.7207
# Estimator 66/100, Train metric: 9.5197
# Estimator 67/100, Train metric: 9.3121
# Estimator 68/100, Train metric: 9.1222
# Estimator 69/100, Train metric: 8.9515
# Estimator 70/100, Train metric: 8.7664
# Estimator 71/100, Train metric: 8.5980
# Estimator 72/100, Train metric: 8.4313
# Estimator 73/100, Train metric: 8.2650
# Estimator 74/100, Train metric: 8.1076
# Estimator 75/100, Train metric: 7.9533
# Estimator 76/100, Train metric: 7.7946
# Estimator 77/100, Train metric: 7.6431
# Estimator 78/100, Train metric: 7.4966
# Estimator 79/100, Train metric: 7.3467
# Estimator 80/100, Train metric: 7.2095
# Estimator 81/100, Train metric: 7.0761
# Estimator 82/100, Train metric: 6.9463
# Estimator 83/100, Train metric: 6.8142
# Estimator 84/100, Train metric: 6.6210
# Estimator 85/100, Train metric: 6.5004
# Estimator 86/100, Train metric: 6.3889
# Estimator 87/100, Train metric: 6.2759
# Estimator 88/100, Train metric: 6.1634
# Estimator 89/100, Train metric: 6.0506
# Estimator 90/100, Train metric: 5.9376
# Estimator 91/100, Train metric: 5.8370
# Estimator 92/100, Train metric: 5.7358
# Estimator 93/100, Train metric: 5.6274
# Estimator 94/100, Train metric: 5.5268
# Estimator 95/100, Train metric: 5.4259
# Estimator 96/100, Train metric: 5.2661
# Estimator 97/100, Train metric: 5.1645
# Estimator 98/100, Train metric: 5.0756
# Estimator 99/100, Train metric: 4.9898
# Estimator 0/100, Train metric: 314.2628
# Estimator 1/100, Train metric: 288.3171
# Estimator 2/100, Train metric: 264.4063
# Estimator 3/100, Train metric: 242.7597
# Estimator 4/100, Train metric: 223.0668
# Estimator 5/100, Train metric: 204.9317
# Estimator 6/100, Train metric: 188.8097
# Estimator 7/100, Train metric: 173.6307
# Estimator 8/100, Train metric: 160.1233
# Estimator 9/100, Train metric: 147.9129
# Estimator 10/100, Train metric: 136.7350
# Estimator 11/100, Train metric: 126.6689
# Estimator 12/100, Train metric: 117.4870
# Estimator 13/100, Train metric: 109.0832
# Estimator 14/100, Train metric: 101.4455
# Estimator 15/100, Train metric: 94.5047
# Estimator 16/100, Train metric: 87.4616
# Estimator 17/100, Train metric: 81.0421
# Estimator 18/100, Train metric: 75.2384
# Estimator 19/100, Train metric: 69.8896
# Estimator 20/100, Train metric: 65.0625
# Estimator 21/100, Train metric: 60.6256
# Estimator 22/100, Train metric: 56.3158
# Estimator 23/100, Train metric: 52.6727
# Estimator 24/100, Train metric: 49.4109
# Estimator 25/100, Train metric: 46.3462
# Estimator 26/100, Train metric: 43.6319
# Estimator 27/100, Train metric: 41.1696
# Estimator 28/100, Train metric: 38.5558
# Estimator 29/100, Train metric: 36.2568
# Estimator 30/100, Train metric: 34.1802
# Estimator 31/100, Train metric: 32.2948
# Estimator 32/100, Train metric: 30.6450
# Estimator 33/100, Train metric: 29.1520
# Estimator 34/100, Train metric: 27.7783
# Estimator 35/100, Train metric: 26.5803
# Estimator 36/100, Train metric: 25.4828
# Estimator 37/100, Train metric: 24.3828
# Estimator 38/100, Train metric: 23.3675
# Estimator 39/100, Train metric: 22.4815
# Estimator 40/100, Train metric: 21.7344
# Estimator 41/100, Train metric: 20.9553
# Estimator 42/100, Train metric: 20.2326
# Estimator 43/100, Train metric: 19.5964
# Estimator 44/100, Train metric: 18.9625
# Estimator 45/100, Train metric: 18.4228
# Estimator 46/100, Train metric: 17.8589
# Estimator 47/100, Train metric: 17.3196
# Estimator 48/100, Train metric: 16.8436
# Estimator 49/100, Train metric: 16.3951
# Estimator 50/100, Train metric: 15.9573
# Estimator 51/100, Train metric: 15.5772
# Estimator 52/100, Train metric: 15.1887
# Estimator 53/100, Train metric: 14.8466
# Estimator 54/100, Train metric: 14.4695
# Estimator 55/100, Train metric: 14.1457
# Estimator 56/100, Train metric: 13.8203
# Estimator 57/100, Train metric: 13.5226
# Estimator 58/100, Train metric: 13.2299
# Estimator 59/100, Train metric: 12.9183
# Estimator 60/100, Train metric: 12.6505
# Estimator 61/100, Train metric: 12.3826
# Estimator 62/100, Train metric: 12.1187
# Estimator 63/100, Train metric: 11.8491
# Estimator 64/100, Train metric: 11.5965
# Estimator 65/100, Train metric: 11.3646
# Estimator 66/100, Train metric: 11.1370
# Estimator 67/100, Train metric: 10.9321
# Estimator 68/100, Train metric: 10.6986
# Estimator 69/100, Train metric: 10.4973
# Estimator 70/100, Train metric: 10.2988
# Estimator 71/100, Train metric: 10.0949
# Estimator 72/100, Train metric: 9.8839
# Estimator 73/100, Train metric: 9.6963
# Estimator 74/100, Train metric: 9.5124
# Estimator 75/100, Train metric: 9.3271
# Estimator 76/100, Train metric: 9.1558
# Estimator 77/100, Train metric: 8.9789
# Estimator 78/100, Train metric: 8.8171
# Estimator 79/100, Train metric: 8.6495
# Estimator 80/100, Train metric: 8.4906
# Estimator 81/100, Train metric: 8.3408
# Estimator 82/100, Train metric: 8.1910
# Estimator 83/100, Train metric: 7.9539
# Estimator 84/100, Train metric: 7.8066
# Estimator 85/100, Train metric: 7.6642
# Estimator 86/100, Train metric: 7.5257
# Estimator 87/100, Train metric: 7.3914
# Estimator 88/100, Train metric: 7.2653
# Estimator 89/100, Train metric: 7.1365
# Estimator 90/100, Train metric: 7.0176
# Estimator 91/100, Train metric: 6.8961
# Estimator 92/100, Train metric: 6.7783
# Estimator 93/100, Train metric: 6.5822
# Estimator 94/100, Train metric: 6.4706
# Estimator 95/100, Train metric: 6.3576
# Estimator 96/100, Train metric: 6.2426
# Estimator 97/100, Train metric: 6.1357
# Estimator 98/100, Train metric: 6.0193
# Estimator 99/100, Train metric: 5.9167
# CPU times: user 9min 42s, sys: 1min 13s, total: 10min 56s
# Wall time: 1min 46s

# %% [markdown]
# ### Comparing the Neural and ML model
#
# In this section we compare the performance of the ML and NN model.

# %%
with open(f'../predictions/lstm/lstm_{CITY}_dengue_msle.pkl', 'rb') as f:
        data_nn = pickle.load(f)

doenca = 'dengue'
with open(f'../predictions/pgbm/pgbm_{CITY}_{doenca}_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)

# %%
plt.figure()

plt.plot(data_nn['indice'][7:], data_nn['target'][:, -1] * data_nn['factor'] , color = 'black', label = 'data')

plt.plot(data_nn['indice'][7:],data_nn['pred'].iloc[:,-1] * data_nn['factor'], label = 'NN')

plt.plot(data_ml['dates'], data_ml['preds'], label = 'ML')

plt.axvline(data_ml['dates'][data_ml['train_size']], color = 'red', ls = '--', label = 'Train/Test') # refered to the ML model 

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Let's compare the error of this models in the test data:

# %%
print('NN error (RMSE):', mse(data_nn['target'][data_nn['xdata'].shape[0]:, -1] * data_nn['factor'], data_nn['pred'].iloc[data_nn['xdata'].shape[0]:,-1] * data_nn['factor'],  squared = False ))
print('ML error (RMSE):', mse(data_ml['target'][4+ data_ml['train_size']:], data_ml['preds'][data_ml['train_size']:], squared = False))
# Out:
# NN error (RMSE): 40.417860742583564
# ML error (RMSE): 65.38149370512076

# %% [markdown]
# Looking at the error above we can see that besides comsume more time training, the neural network model (nn) outperform the machine learning model (ml)

# %% [markdown]
# We will know use this models to predict the chik outbreak in 2021. In order to do this, we will retrain the nn model and the ml model using the dengue data up to '2021-01-01' and apply the model in the chik data between '2021-01-01' and '2022-01-01'

# %% [markdown]
# The label parameter is used as a flag to make difference, if necessary, between the models saved, since this model takes a lot of time to be trained

# %%
# %%time

model = build_model(hidden = 8, features = 11, predict_n = PREDICT_N, look_back= LOOK_BACK, batch_size=1, loss = 'msle')

make_pred(model, CITY, doenca = 'dengue', epochs = 100, end_train_date = None, 
                ratio= 1, end_date = END_DATE, hidden = 8,
                 predict_n = PREDICT_N, look_back =  LOOK_BACK,
                  label = 'msle_all')
# Out:
# Compilation Time :  0.036141157150268555
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 4, 11)]           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 4, 8)              1280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 8)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 36
# =================================================================
# Total params: 1,860
# Trainable params: 1,860
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on
# Epoch 24/100
# 423/423 [==============================] - 166s 392ms/sample - loss: 0.0038 - accuracy: 0.3121 - mape: 1305911.8750 - mse: 0.0076 - val_loss: 5.2357e-04 - val_accuracy: 0.3028 - val_mape: 69.4590 - val_mse: 5.8844e-04
# CPU times: user 28min 3s, sys: 2min 5s, total: 30min 9s
# Wall time: 23min 14s
#                                     0             1             2  \
# mean_absolute_error         36.719468     41.848592     52.335530
# explained_variance_score     0.923740      0.888784      0.826346
# mean_squared_error        7248.524608  10549.564790  16426.955104
# mean_squared_log_error       0.270210      0.235136      0.265150
# median_absolute_error       13.770719     15.642820     16.850692
# r2_score                     0.921750      0.886093      0.822615
#
#                                      3
# mean_absolute_error          64.563621
# explained_variance_score      0.742168
# mean_squared_error        24614.210940
# mean_squared_log_error        0.296092
# median_absolute_error        20.586558
# r2_score                      0.734184

# %%
preds, preds25, preds975, X_train, targets = qf_prediction(CITY, STATE, PREDICT_N, LOOK_BACK, doenca = 'dengue', ini_date = None, end_train_date = END_DATE, end_date = END_DATE)
# Out:
# Estimator 0/100, Train metric: 277.2414
# Estimator 1/100, Train metric: 253.1052
# Estimator 2/100, Train metric: 231.3162
# Estimator 3/100, Train metric: 211.3680
# Estimator 4/100, Train metric: 193.4560
# Estimator 5/100, Train metric: 177.1896
# Estimator 6/100, Train metric: 162.4106
# Estimator 7/100, Train metric: 148.7635
# Estimator 8/100, Train metric: 136.4152
# Estimator 9/100, Train metric: 125.2153
# Estimator 10/100, Train metric: 114.9886
# Estimator 11/100, Train metric: 105.7154
# Estimator 12/100, Train metric: 97.2706
# Estimator 13/100, Train metric: 89.4899
# Estimator 14/100, Train metric: 82.5028
# Estimator 15/100, Train metric: 76.1422
# Estimator 16/100, Train metric: 70.0139
# Estimator 17/100, Train metric: 64.4414
# Estimator 18/100, Train metric: 59.4109
# Estimator 19/100, Train metric: 54.8416
# Estimator 20/100, Train metric: 50.7733
# Estimator 21/100, Train metric: 47.0891
# Estimator 22/100, Train metric: 43.5474
# Estimator 23/100, Train metric: 40.3728
# Estimator 24/100, Train metric: 37.5553
# Estimator 25/100, Train metric: 35.0322
# Estimator 26/100, Train metric: 32.5466
# Estimator 27/100, Train metric: 30.2827
# Estimator 28/100, Train metric: 28.2319
# Estimator 29/100, Train metric: 26.3368
# Estimator 30/100, Train metric: 24.5911
# Estimator 31/100, Train metric: 23.0130
# Estimator 32/100, Train metric: 21.5401
# Estimator 33/100, Train metric: 20.2804
# Estimator 34/100, Train metric: 19.1649
# Estimator 35/100, Train metric: 18.1606
# Estimator 36/100, Train metric: 17.2577
# Estimator 37/100, Train metric: 16.3450
# Estimator 38/100, Train metric: 15.5794
# Estimator 39/100, Train metric: 14.7070
# Estimator 40/100, Train metric: 13.9292
# Estimator 41/100, Train metric: 13.2360
# Estimator 42/100, Train metric: 12.6153
# Estimator 43/100, Train metric: 12.0359
# Estimator 44/100, Train metric: 11.5110
# Estimator 45/100, Train metric: 11.0373
# Estimator 46/100, Train metric: 10.5864
# Estimator 47/100, Train metric: 10.1736
# Estimator 48/100, Train metric: 9.8341
# Estimator 49/100, Train metric: 9.4241
# Estimator 50/100, Train metric: 9.0821
# Estimator 51/100, Train metric: 8.7299
# Estimator 52/100, Train metric: 8.4344
# Estimator 53/100, Train metric: 8.1124
# Estimator 54/100, Train metric: 7.8089
# Estimator 55/100, Train metric: 7.5817
# Estimator 56/100, Train metric: 7.3665
# Estimator 57/100, Train metric: 7.1540
# Estimator 58/100, Train metric: 6.9445
# Estimator 59/100, Train metric: 6.7955
# Estimator 60/100, Train metric: 6.6020
# Estimator 61/100, Train metric: 6.4539
# Estimator 62/100, Train metric: 6.3151
# Estimator 63/100, Train metric: 6.1645
# Estimator 64/100, Train metric: 6.0031
# Estimator 65/100, Train metric: 5.8849
# Estimator 66/100, Train metric: 5.7439
# Estimator 67/100, Train metric: 5.5826
# Estimator 68/100, Train metric: 5.4729
# Estimator 69/100, Train metric: 5.2871
# Estimator 70/100, Train metric: 5.1454
# Estimator 71/100, Train metric: 5.0085
# Estimator 72/100, Train metric: 4.8982
# Estimator 73/100, Train metric: 4.8027
# Estimator 74/100, Train metric: 4.6813
# Estimator 75/100, Train metric: 4.5841
# Estimator 76/100, Train metric: 4.4766
# Estimator 77/100, Train metric: 4.3600
# Estimator 78/100, Train metric: 4.2453
# Estimator 79/100, Train metric: 4.1356
# Estimator 80/100, Train metric: 4.0267
# Estimator 81/100, Train metric: 3.9257
# Estimator 82/100, Train metric: 3.8423
# Estimator 83/100, Train metric: 3.7646
# Estimator 84/100, Train metric: 3.6900
# Estimator 85/100, Train metric: 3.6179
# Estimator 86/100, Train metric: 3.5434
# Estimator 87/100, Train metric: 3.4724
# Estimator 88/100, Train metric: 3.3859
# Estimator 89/100, Train metric: 3.3144
# Estimator 90/100, Train metric: 3.2541
# Estimator 91/100, Train metric: 3.1970
# Estimator 92/100, Train metric: 3.1133
# Estimator 93/100, Train metric: 3.0329
# Estimator 94/100, Train metric: 2.9708
# Estimator 95/100, Train metric: 2.9116
# Estimator 96/100, Train metric: 2.8342
# Estimator 97/100, Train metric: 2.7827
# Estimator 98/100, Train metric: 2.7222
# Estimator 99/100, Train metric: 2.6511
# Estimator 0/100, Train metric: 277.8889
# Estimator 1/100, Train metric: 253.9518
# Estimator 2/100, Train metric: 232.3550
# Estimator 3/100, Train metric: 212.8174
# Estimator 4/100, Train metric: 195.0760
# Estimator 5/100, Train metric: 178.8635
# Estimator 6/100, Train metric: 164.1810
# Estimator 7/100, Train metric: 150.7561
# Estimator 8/100, Train metric: 138.5535
# Estimator 9/100, Train metric: 127.3838
# Estimator 10/100, Train metric: 117.2501
# Estimator 11/100, Train metric: 108.0598
# Estimator 12/100, Train metric: 99.7008
# Estimator 13/100, Train metric: 91.8704
# Estimator 14/100, Train metric: 84.9024
# Estimator 15/100, Train metric: 78.6225
# Estimator 16/100, Train metric: 72.7034
# Estimator 17/100, Train metric: 67.2506
# Estimator 18/100, Train metric: 62.3960
# Estimator 19/100, Train metric: 57.6336
# Estimator 20/100, Train metric: 53.2215
# Estimator 21/100, Train metric: 49.2171
# Estimator 22/100, Train metric: 45.5784
# Estimator 23/100, Train metric: 42.3532
# Estimator 24/100, Train metric: 39.4029
# Estimator 25/100, Train metric: 36.8264
# Estimator 26/100, Train metric: 34.4690
# Estimator 27/100, Train metric: 32.3431
# Estimator 28/100, Train metric: 30.2192
# Estimator 29/100, Train metric: 28.2034
# Estimator 30/100, Train metric: 26.4142
# Estimator 31/100, Train metric: 24.7367
# Estimator 32/100, Train metric: 23.2808
# Estimator 33/100, Train metric: 21.8588
# Estimator 34/100, Train metric: 20.6909
# Estimator 35/100, Train metric: 19.5038
# Estimator 36/100, Train metric: 18.4336
# Estimator 37/100, Train metric: 17.4791
# Estimator 38/100, Train metric: 16.6087
# Estimator 39/100, Train metric: 15.8327
# Estimator 40/100, Train metric: 15.1089
# Estimator 41/100, Train metric: 14.4286
# Estimator 42/100, Train metric: 13.7762
# Estimator 43/100, Train metric: 13.2066
# Estimator 44/100, Train metric: 12.6814
# Estimator 45/100, Train metric: 12.1848
# Estimator 46/100, Train metric: 11.7440
# Estimator 47/100, Train metric: 11.3404
# Estimator 48/100, Train metric: 10.8976
# Estimator 49/100, Train metric: 10.5586
# Estimator 50/100, Train metric: 10.2230
# Estimator 51/100, Train metric: 9.9464
# Estimator 52/100, Train metric: 9.6233
# Estimator 53/100, Train metric: 9.3121
# Estimator 54/100, Train metric: 9.0545
# Estimator 55/100, Train metric: 8.8144
# Estimator 56/100, Train metric: 8.6099
# Estimator 57/100, Train metric: 8.3959
# Estimator 58/100, Train metric: 8.1817
# Estimator 59/100, Train metric: 7.9456
# Estimator 60/100, Train metric: 7.6927
# Estimator 61/100, Train metric: 7.5136
# Estimator 62/100, Train metric: 7.3029
# Estimator 63/100, Train metric: 7.1119
# Estimator 64/100, Train metric: 6.9358
# Estimator 65/100, Train metric: 6.7589
# Estimator 66/100, Train metric: 6.5989
# Estimator 67/100, Train metric: 6.4567
# Estimator 68/100, Train metric: 6.3033
# Estimator 69/100, Train metric: 6.1527
# Estimator 70/100, Train metric: 6.0354
# Estimator 71/100, Train metric: 5.9278
# Estimator 72/100, Train metric: 5.8209
# Estimator 73/100, Train metric: 5.6839
# Estimator 74/100, Train metric: 5.5795
# Estimator 75/100, Train metric: 5.4433
# Estimator 76/100, Train metric: 5.3435
# Estimator 77/100, Train metric: 5.2149
# Estimator 78/100, Train metric: 5.0804
# Estimator 79/100, Train metric: 4.9502
# Estimator 80/100, Train metric: 4.8354
# Estimator 81/100, Train metric: 4.7546
# Estimator 82/100, Train metric: 4.6349
# Estimator 83/100, Train metric: 4.5434
# Estimator 84/100, Train metric: 4.4592
# Estimator 85/100, Train metric: 4.3943
# Estimator 86/100, Train metric: 4.3233
# Estimator 87/100, Train metric: 4.2256
# Estimator 88/100, Train metric: 4.1350
# Estimator 89/100, Train metric: 4.0304
# Estimator 90/100, Train metric: 3.9341
# Estimator 91/100, Train metric: 3.8755
# Estimator 92/100, Train metric: 3.7821
# Estimator 93/100, Train metric: 3.6962
# Estimator 94/100, Train metric: 3.5978
# Estimator 95/100, Train metric: 3.5157
# Estimator 96/100, Train metric: 3.4295
# Estimator 97/100, Train metric: 3.3417
# Estimator 98/100, Train metric: 3.2736
# Estimator 99/100, Train metric: 3.2084
# Estimator 0/100, Train metric: 278.4805
# Estimator 1/100, Train metric: 255.1186
# Estimator 2/100, Train metric: 233.9943
# Estimator 3/100, Train metric: 214.8949
# Estimator 4/100, Train metric: 197.3513
# Estimator 5/100, Train metric: 181.3830
# Estimator 6/100, Train metric: 166.7962
# Estimator 7/100, Train metric: 153.6493
# Estimator 8/100, Train metric: 141.5532
# Estimator 9/100, Train metric: 130.5940
# Estimator 10/100, Train metric: 120.5483
# Estimator 11/100, Train metric: 111.5098
# Estimator 12/100, Train metric: 103.3662
# Estimator 13/100, Train metric: 95.3498
# Estimator 14/100, Train metric: 88.6205
# Estimator 15/100, Train metric: 81.8909
# Estimator 16/100, Train metric: 75.7877
# Estimator 17/100, Train metric: 70.3701
# Estimator 18/100, Train metric: 65.5136
# Estimator 19/100, Train metric: 60.9750
# Estimator 20/100, Train metric: 56.8705
# Estimator 21/100, Train metric: 53.0590
# Estimator 22/100, Train metric: 49.6835
# Estimator 23/100, Train metric: 46.6044
# Estimator 24/100, Train metric: 43.4634
# Estimator 25/100, Train metric: 40.6135
# Estimator 26/100, Train metric: 38.0412
# Estimator 27/100, Train metric: 35.7033
# Estimator 28/100, Train metric: 33.5278
# Estimator 29/100, Train metric: 31.5718
# Estimator 30/100, Train metric: 29.6207
# Estimator 31/100, Train metric: 27.8387
# Estimator 32/100, Train metric: 26.2494
# Estimator 33/100, Train metric: 24.8422
# Estimator 34/100, Train metric: 23.5817
# Estimator 35/100, Train metric: 22.4183
# Estimator 36/100, Train metric: 21.3928
# Estimator 37/100, Train metric: 20.4715
# Estimator 38/100, Train metric: 19.6729
# Estimator 39/100, Train metric: 18.9411
# Estimator 40/100, Train metric: 18.2004
# Estimator 41/100, Train metric: 17.5426
# Estimator 42/100, Train metric: 16.9745
# Estimator 43/100, Train metric: 16.3847
# Estimator 44/100, Train metric: 15.8513
# Estimator 45/100, Train metric: 15.3452
# Estimator 46/100, Train metric: 14.8895
# Estimator 47/100, Train metric: 14.4672
# Estimator 48/100, Train metric: 14.0258
# Estimator 49/100, Train metric: 13.6231
# Estimator 50/100, Train metric: 13.2819
# Estimator 51/100, Train metric: 12.9002
# Estimator 52/100, Train metric: 12.5633
# Estimator 53/100, Train metric: 12.2628
# Estimator 54/100, Train metric: 11.9734
# Estimator 55/100, Train metric: 11.7182
# Estimator 56/100, Train metric: 11.4381
# Estimator 57/100, Train metric: 11.1566
# Estimator 58/100, Train metric: 10.9136
# Estimator 59/100, Train metric: 10.7072
# Estimator 60/100, Train metric: 10.4790
# Estimator 61/100, Train metric: 10.2614
# Estimator 62/100, Train metric: 10.0187
# Estimator 63/100, Train metric: 9.8194
# Estimator 64/100, Train metric: 9.6344
# Estimator 65/100, Train metric: 9.4392
# Estimator 66/100, Train metric: 9.2261
# Estimator 67/100, Train metric: 9.0300
# Estimator 68/100, Train metric: 8.8645
# Estimator 69/100, Train metric: 8.6570
# Estimator 70/100, Train metric: 8.4949
# Estimator 71/100, Train metric: 8.3124
# Estimator 72/100, Train metric: 8.1354
# Estimator 73/100, Train metric: 7.9582
# Estimator 74/100, Train metric: 7.8078
# Estimator 75/100, Train metric: 7.6581
# Estimator 76/100, Train metric: 7.4974
# Estimator 77/100, Train metric: 7.3557
# Estimator 78/100, Train metric: 7.2041
# Estimator 79/100, Train metric: 7.0351
# Estimator 80/100, Train metric: 6.8777
# Estimator 81/100, Train metric: 6.7322
# Estimator 82/100, Train metric: 6.5670
# Estimator 83/100, Train metric: 6.4299
# Estimator 84/100, Train metric: 6.3188
# Estimator 85/100, Train metric: 6.1943
# Estimator 86/100, Train metric: 6.0752
# Estimator 87/100, Train metric: 5.9773
# Estimator 88/100, Train metric: 5.8615
# Estimator 89/100, Train metric: 5.7596
# Estimator 90/100, Train metric: 5.6534
# Estimator 91/100, Train metric: 5.5491
# Estimator 92/100, Train metric: 5.4377
# Estimator 93/100, Train metric: 5.3464
# Estimator 94/100, Train metric: 5.2554
# Estimator 95/100, Train metric: 5.1609
# Estimator 96/100, Train metric: 5.0777
# Estimator 97/100, Train metric: 4.9935
# Estimator 98/100, Train metric: 4.9096
# Estimator 99/100, Train metric: 4.8211
# Estimator 0/100, Train metric: 278.8182
# Estimator 1/100, Train metric: 255.8263
# Estimator 2/100, Train metric: 234.6727
# Estimator 3/100, Train metric: 215.5571
# Estimator 4/100, Train metric: 198.2922
# Estimator 5/100, Train metric: 182.6379
# Estimator 6/100, Train metric: 168.4301
# Estimator 7/100, Train metric: 155.6088
# Estimator 8/100, Train metric: 143.8061
# Estimator 9/100, Train metric: 132.9642
# Estimator 10/100, Train metric: 123.1735
# Estimator 11/100, Train metric: 114.2369
# Estimator 12/100, Train metric: 106.0384
# Estimator 13/100, Train metric: 98.6239
# Estimator 14/100, Train metric: 90.9393
# Estimator 15/100, Train metric: 84.0295
# Estimator 16/100, Train metric: 77.8915
# Estimator 17/100, Train metric: 72.3164
# Estimator 18/100, Train metric: 67.2383
# Estimator 19/100, Train metric: 62.6417
# Estimator 20/100, Train metric: 58.2210
# Estimator 21/100, Train metric: 54.4373
# Estimator 22/100, Train metric: 50.9303
# Estimator 23/100, Train metric: 47.8199
# Estimator 24/100, Train metric: 44.9174
# Estimator 25/100, Train metric: 42.3352
# Estimator 26/100, Train metric: 39.8732
# Estimator 27/100, Train metric: 37.7140
# Estimator 28/100, Train metric: 35.5402
# Estimator 29/100, Train metric: 33.6107
# Estimator 30/100, Train metric: 31.8848
# Estimator 31/100, Train metric: 30.2702
# Estimator 32/100, Train metric: 28.8292
# Estimator 33/100, Train metric: 27.4989
# Estimator 34/100, Train metric: 26.3326
# Estimator 35/100, Train metric: 25.2316
# Estimator 36/100, Train metric: 24.2323
# Estimator 37/100, Train metric: 23.2730
# Estimator 38/100, Train metric: 22.4947
# Estimator 39/100, Train metric: 21.6396
# Estimator 40/100, Train metric: 20.9718
# Estimator 41/100, Train metric: 20.2459
# Estimator 42/100, Train metric: 19.5908
# Estimator 43/100, Train metric: 18.8100
# Estimator 44/100, Train metric: 18.2130
# Estimator 45/100, Train metric: 17.6414
# Estimator 46/100, Train metric: 17.1803
# Estimator 47/100, Train metric: 16.6988
# Estimator 48/100, Train metric: 16.1029
# Estimator 49/100, Train metric: 15.6443
# Estimator 50/100, Train metric: 15.2246
# Estimator 51/100, Train metric: 14.8473
# Estimator 52/100, Train metric: 14.5049
# Estimator 53/100, Train metric: 14.1801
# Estimator 54/100, Train metric: 13.8349
# Estimator 55/100, Train metric: 13.5137
# Estimator 56/100, Train metric: 13.2200
# Estimator 57/100, Train metric: 12.9423
# Estimator 58/100, Train metric: 12.6636
# Estimator 59/100, Train metric: 12.3855
# Estimator 60/100, Train metric: 12.0817
# Estimator 61/100, Train metric: 11.8349
# Estimator 62/100, Train metric: 11.5837
# Estimator 63/100, Train metric: 11.3156
# Estimator 64/100, Train metric: 11.1124
# Estimator 65/100, Train metric: 10.8879
# Estimator 66/100, Train metric: 10.6712
# Estimator 67/100, Train metric: 10.4393
# Estimator 68/100, Train metric: 10.2124
# Estimator 69/100, Train metric: 10.0051
# Estimator 70/100, Train metric: 9.8036
# Estimator 71/100, Train metric: 9.5894
# Estimator 72/100, Train metric: 9.4037
# Estimator 73/100, Train metric: 9.2154
# Estimator 74/100, Train metric: 9.0351
# Estimator 75/100, Train metric: 8.8575
# Estimator 76/100, Train metric: 8.6759
# Estimator 77/100, Train metric: 8.5348
# Estimator 78/100, Train metric: 8.3505
# Estimator 79/100, Train metric: 8.2054
# Estimator 80/100, Train metric: 8.0630
# Estimator 81/100, Train metric: 7.8574
# Estimator 82/100, Train metric: 7.7083
# Estimator 83/100, Train metric: 7.5793
# Estimator 84/100, Train metric: 7.4196
# Estimator 85/100, Train metric: 7.2809
# Estimator 86/100, Train metric: 7.1497
# Estimator 87/100, Train metric: 7.0144
# Estimator 88/100, Train metric: 6.8767
# Estimator 89/100, Train metric: 6.7436
# Estimator 90/100, Train metric: 6.6051
# Estimator 91/100, Train metric: 6.4885
# Estimator 92/100, Train metric: 6.3742
# Estimator 93/100, Train metric: 6.2659
# Estimator 94/100, Train metric: 6.1590
# Estimator 95/100, Train metric: 6.0557
# Estimator 96/100, Train metric: 5.9526
# Estimator 97/100, Train metric: 5.8413
# Estimator 98/100, Train metric: 5.7327
# Estimator 99/100, Train metric: 5.5770

# %% [markdown]
# Apply the ml model in chik:
#
# The predictions are saved in the path: './predictions/pgbm/pgbm_{city}_chik_cross_predictions.pkl'

# %%
preds, preds25, preds975, X_data, targets = cross_dengue_chik_prediction(CITY, STATE, predict_n = PREDICT_N, look_back = LOOK_BACK, ini_date = INI_DATE_CHIK, end_date = END_DATE_CHIK)

# %% [markdown]
# Apply the NN model into the chik data:
#
# The predictions is saved in the path: './predictions/lstm/lstm_{city}_dengue_model_chik_predictions.pkl'

# %%
metrics = apply_dengue_chik(CITY_NAME, CITY, ini_date = INI_DATE_CHIK, 
                     end_date = END_DATE_CHIK, look_back = LOOK_BACK,
                     predict_n = PREDICT_N,  label_m = f'msle_all' )

# %% [markdown]
# Compare the predictions:

# %%
with open(f'../predictions/lstm/lstm_{CITY}_dengue_model_chik_predictions.pkl', 'rb') as f:
        data_nn = pickle.load(f)

doenca = 'dengue'
with open(f'../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)
        
plt.figure()

plt.plot(data_nn['indice'][7:], data_nn['target'][:, -1] * data_nn['factor'] , color = 'black', label = 'data')

plt.plot(data_nn['indice'][7:],data_nn['pred'].iloc[:,-1] * data_nn['factor'], label = 'NN')

plt.plot(data_ml['dates'], data_ml['preds'], label = 'ML')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Compute the RMSE error:

# %%
print('NN error (RMSE):', mse(data_nn['target'][:, -1] * data_nn['factor'], data_nn['pred'].iloc[:,-1] * data_nn['factor'],  squared = False ))
print('ML error (RMSE):', mse(data_ml['target'][4:], data_ml['preds'], squared = False))
# Out:
# NN error (RMSE): 298.7737094124811
# ML error (RMSE): 333.60882586486804

# %% [markdown]
# ### Transfer learning
#
# Here we use the transfer learning technique to improve the performance of the predictions of the dengue model in the chik data. To do this, we retrain the output layer of the dengue model, and after it, retrain the model (all the layers, that's the fine tunning step). In this step, we need to pay attention to overfitting. It can be necessary to decrease the learning rate.
#
# We use the transfer learning technique since it is not possible to train a good ml or nn model with few observations, as in the case of the  chik outbreak in Recife in 2021.

# %%
transf_chik_pred(CITY_NAME, CITY, ini_date = INI_DATE_CHIK, end_train_date = END_TRAIN_CHIK,  
                            end_date = END_DATE_CHIK, filename = f'../saved_models/lstm/trained_{CITY}_model_msle_all.h5',  epochs =100, features = 11,  
                            predict_n = 4, look_back = 4, loss = 'msle', validation_split = 0.0,
                            label = f'transf_chik')
# Out:
# 2022-08-31 15:55:25.677275: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-31 15:55:25.678259: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# Compilation Time :  0.030804872512817383
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4, 11)]           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 4, 8)              1280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 8)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 36
# =================================================================
# Total params: 1,860
# Trainable params: 36
# Non-trainable params: 1,824
# _________________________________________________________________
# None
# Train on 10 samples
# Epoch 1/100
#  2/10 [=====>........................] - ETA: 15s - loss: 0.0152 - accuracy: 0.0000e+00 - mape: 94.2694 - mse: 0.0185
# 2022-08-31 15:55:30.074408: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.
# 10/10 [==============================] - 4s 408ms/sample - loss: 0.0062 - accuracy: 0.1000 - mape: 78.1538 - mse: 0.0073
# Epoch 2/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0053 - accuracy: 0.1000 - mape: 65.9806 - mse: 0.0063
# Epoch 3/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0045 - accuracy: 0.1000 - mape: 54.4242 - mse: 0.0054
# Epoch 4/100
# 10/10 [==============================] - 0s 14ms/sample - loss: 0.0038 - accuracy: 0.2000 - mape: 50.1564 - mse: 0.0046
# Epoch 5/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.
100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0015 - accuracy: 0.7000 - mape: 58.0572 - mse: 0.0018
# Epoch 80/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0012 - accuracy: 0.7000 - mape: 48.7790 - mse: 0.0016
# Epoch 81/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0014 - accuracy: 0.7000 - mape: 52.9055 - mse: 0.0018
# 2022-08-31 15:55:45.037937: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.

# %% [markdown]
# To apply the transfer learning technique we use as train data the chik data up to '2021-05-01'. We can see that after this day the model has good performance considering the next month (data between '2021-05-01' and '2021-06-01').
#
# To evaluate the improvement in the performance of the model we compute the following skill score:
#
# $$ SS = 1 - \cfrac{RMSE_{forecast}}{RMSE_{reference}}$$
#
# In the formula, the reference represent the error of the model used as reference and the forecast represent the new model that we want to compare the performance. If the SS value is above 0 or new model is better than the reference model, otherwise it's worst.

# %%
def ss(forecast, reference, target):
    
    rmse_f = mse(target, forecast, squared = False )
    
    rmse_r = mse(target, reference, squared = False)
    
    return 1 - (rmse_f/rmse_r)

# %%
with open(f'../predictions/lstm/lstm_{CITY}_dengue_model_chik_predictions.pkl', 'rb') as f:
        data_nn = pickle.load(f)

doenca = 'dengue'
with open(f'../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)

with open(f'predictions/lstm/tl_{CITY}_transf_chik.pkl', 'rb') as f:
        data_tl = pickle.load(f) 
        

plt.figure()

plt.plot(data_nn['indice'][7:], data_nn['target'][:, -1] * data_nn['factor'] , color = 'black', label = 'data')

plt.plot(data_nn['indice'][7:],data_nn['pred'].iloc[:,-1] * data_nn['factor'], label = 'NN')

plt.plot(data_tl['indice'][7:],data_tl['pred'].iloc[:,-1] * data_tl['factor'], label = 'TL')

plt.plot(data_ml['dates'], data_ml['preds'], label = 'ML')

plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
from datetime import datetime
ini_index = data_nn['indice'].index(datetime.strptime(INI_EVALUATE, '%Y-%m-%d'))
end_index = data_nn['indice'].index(datetime.strptime(END_EVALUATE, '%Y-%m-%d'))

print('SS compared to NN:', ss( target = data_tl['target'][ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              forecast = data_tl['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              reference = data_nn['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_nn['factor']))
print('SS compared to ML:', ss( target = data_tl['target'][ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              forecast = data_tl['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              reference = data_ml['preds'][ data_ml['dates'].index(datetime.strptime(INI_EVALUATE, '%Y-%m-%d')): data_ml['dates'].index(datetime.strptime(END_EVALUATE, '%Y-%m-%d'))] ))
# Out:
# SS compared to NN: 0.41314487441646564
# SS compared to ML: 0.49489063033603164

# %% [markdown]
# ### Retrain the dengue model with a custom loss function

# %% [markdown]
# To specialize our lstm dengue model to predict better the peak of cases we propose a custom loss function. This function gives a weight of 10 to the predictions of ascending cases in the train data.
#
# This weight is given to the observations in the training data, where the fourth value is bigger than the second value of the target data. (Remember it is an array of length four since we forecast the next 4 observations).
#
# ```
# def custom_loss_msle(p = 1):
#     """
#     :param p:
#     """
#
#     def my_loss_msle(y_true, y_pred):
#         """
#         :param y_true:
#         :param y_pred:
#         """
#
#         def f1():
#
#             loss = tf.math.log(tf.math.add(y_true, 1)/ tf.math.add(y_pred, 1))
#
#             loss = tf.square(loss)
#
#             return tf.multiply(loss, p)
#
#         def f2():
#
#             loss = tf.math.log(tf.math.add(y_true, 1)/ tf.math.add(y_pred, 1))
#
#             loss = tf.square(loss)
#
#             return loss
#
#         msle = tf.cond(tf.less(tf.gather(y_true, 0)[1],tf.gather(y_true, 0)[3]) ,
#                                      true_fn = f1,
#                                      false_fn = f2 )
#
#         return tf.reduce_mean(msle)
#
#     return my_loss_msle
# ```

# %%
from lstm import custom_loss_msle

# %%
# %%time
model = build_model(hidden = 8, features = 11, predict_n = PREDICT_N, look_back = LOOK_BACK, batch_size=1, loss = custom_loss_msle(p=10))

make_pred(model, CITY, doenca = 'dengue', epochs = 100, end_train_date = None, 
                ratio= 1.0, end_date = END_DATE, hidden = 8,
                 predict_n = PREDICT_N, look_back =  LOOK_BACK,
                  label = 'custom_msle')
# Out:
# Compilation Time :  0.04587388038635254
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 4, 11)]           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 4, 8)              1280
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 8)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 36
# =================================================================
# Total params: 1,860
# Trainable params: 1,860
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 423 samples, validate on 142 samples
# Epoch 1/100
#   2/423 [..............................] - ETA: 19:55 - loss: 0.0774 - accuracy: 0.5000 - mape: 534910.6250 - mse: 0.0088
# 2022-08-31 13:35:32.371037: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.
# 423/423 [==============================] - 12s 29ms/sample - loss: 0.1181 - accuracy: 0.2790 - mape: 3915337.7500 - mse: 0.0368 - val_loss: 0.0107 - val_accuracy: 0.3239 - val_mape: 165.8605 - val_mse: 0.0022
# Epoch 2/100
# 423/423 [==============================] - 6s 14ms/sample - loss: 0.0757 - accuracy: 0.3664 - mape: 2738341.7500 - mse: 0.0236 - val_loss: 0.0146 - val_accuracy: 0.2746 - val_mape: 147.2470 - val_mse: 0.0033
# Epoch 3/100
# 423/423 [==============================] - 6s 14ms/sample - loss: 0.0636 - accuracy: 0.3168 - mape: 1451252.2500 - mse: 0.0203 - val_loss: 0.0109 - val_accuracy: 0.3310 - val_mape: 128.0408 - val_mse: 0.0031
# Epoch 4/100
# 423/423 [==============================] - 6s 13ms/sample - loss: 0.0597 - accuracy: 0.3333 - mape: 1632858.6250 - mse: 0.0187 - val_loss: 0.0107 - val_accuracy: 0.2958 - val_mape: 116.6713 - val_mse: 0.0022
# Epoch 5/100
# 423/423 [==============================] - 6s 13ms/sample - loss: 0.0436 - accuracy: 0.2955 - mape: 2248097.2500 - mse: 0.0160 - val_loss: 0.0048 - val_accuracy: 0.2113 - val_mape: 99.0843 - val_mse: 0.0012
# Epoch 6/100
# 423/423 [==============================] - 31s 74ms/sample - loss: 0.0283 - accuracy: 0.2955 - mape: 2375907.0000 - mse: 0.0115 - val_loss: 0.0058 - val_accuracy: 0.2817 - val_mape: 95.6994 - val_mse: 0.0011
# Epoch 7/100
# 423/423 [==============================] - 40s 94ms/sample - loss: 0.0250 - accuracy: 0.2861 - mape: 2725599.0000 - mse: 0.0136 - val_loss: 0.0077 - val_accuracy: 0.2887 - val_mape: 113.6388 - val_mse: 0.0022
# 423/423 [==============================] - 29s 68ms/sample - loss: 0.0189 - accuracy: 0.3097 - mape: 2297391.7500 - mse: 0.0095 - val_loss: 0.0043 - val_accuracy: 0.2887 - val_mape: 79.8089 - val_mse: 7.6365e-04
# Epoch 20/100
# 423/423 [==============================] - 29s 68ms/sample - loss: 0.0198 - accuracy: 0.3286 - mape: 1776941.1250 - mse: 0.0093 - val_loss: 0.0041 - val_accuracy: 0.2606 - val_mape: 91.1125 - val_mse: 0.0010
# Epoch 21/100
# 423/423 [==============================] - 23s 54ms/sample - loss: 0.0227 - accuracy: 0.3026 - mape: 2142565.2500 - mse: 0.0104 - val_loss: 0.0039 - val_accuracy: 0.2465 - val_mape: 88.7431 - val_mse: 8.2396e-04
# Epoch 22/100
# 423/423 [==============================] - 25s 59ms/sample - loss: 0.0205 - accuracy: 0.3050 - mape: 1837391.1250 - mse: 0.0093 - val_loss: 0.0046 - val_accuracy: 0.2606 - val_mape: 73.4108 - val_mse: 7.8362e-04
# CPU times: user 22min 43s, sys: 1min 50s, total: 24min 33s
# Wall time: 18min 19s
#                                     0             1             2  \
# mean_absolute_error         46.709047     59.437402     71.562075
# explained_variance_score     0.900044      0.845808      0.772244
# mean_squared_error        9736.715825  14789.439664  21222.585163
# mean_squared_log_error       0.526784      0.615222      0.853333
# median_absolute_error       22.431731     25.336126     26.988225
# r2_score                     0.894889      0.840314      0.770830
#
#                                      3
# mean_absolute_error          83.912204
# explained_variance_score      0.634752
# mean_squared_error        33984.641378
# mean_squared_log_error        0.633426
# median_absolute_error        25.456996
# r2_score                      0.632990

# %% [markdown]
# See the behaviour of this model when applied in the chik data:

# %%
# %%time
metrics = apply_dengue_chik(CITY_NAME, CITY, ini_date = INI_DATE_CHIK, 
                     end_date = END_DATE_CHIK, look_back = LOOK_BACK,
                     predict_n = PREDICT_N,  label_m = f'custom_msle' )
# Out:
# CPU times: user 22.3 s, sys: 1.63 s, total: 23.9 s
# Wall time: 12.8 s

# %%
with open(f'../predictions/lstm/lstm_{CITY}_dengue_model_chik_predictions.pkl', 'rb') as f:
        data_nn = pickle.load(f)

doenca = 'dengue'
with open(f'../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)
        
plt.figure()

plt.plot(data_nn['indice'][7:], data_nn['target'][:, -1] * data_nn['factor'] , color = 'black', label = 'data')

plt.plot(data_nn['indice'][7:],data_nn['pred'].iloc[:,-1] * data_nn['factor'], label = 'NN')

plt.plot(data_ml['dates'], data_ml['preds'], label = 'ML')

plt.grid()
plt.legend()
plt.xticks(rotation = 45)
plt.show()

# %%
print('NN error (RMSE):', mse(data_nn['target'][:, -1] * data_nn['factor'], data_nn['pred'].iloc[:,-1] * data_nn['factor'],  squared = False ))
print('ML error (RMSE):', mse(data_ml['target'][4:], data_ml['preds'], squared = False))
# Out:
# NN error (RMSE): 338.28111005422863
# ML error (RMSE): 333.60882586486804

# %% [markdown]
# Apply the transfer learning technique using this new trained model:

# %%
# %%time
transf_chik_pred(CITY_NAME, CITY, ini_date = INI_DATE_CHIK, end_train_date = END_TRAIN_CHIK,  
                            end_date = END_DATE_CHIK, filename = f'../saved_models/lstm/trained_{CITY}_model_custom_msle.h5',  epochs =100, features = 11,  
                            predict_n = PREDICT_N, look_back = LOOK_BACK, loss = custom_loss_msle(p=10), validation_split = 0.0,
                            label = f'transf_chik')
# Out:
# Compilation Time :  0.03490400314331055
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None,
100
# 10/10 [==============================] - 0s 12ms/sample - loss: 0.0215 - accuracy: 0.7000 - mape: 70.0507 - mse: 0.0028
# Epoch 24/100
# 10/10 [==============================] - 0s 12ms/sample - loss: 0.0221 - accuracy: 0.7000 - mape: 70.8198 - mse: 0.0028
# Epoch 25/100
# 10/10 [==============================] - 0s 12ms/sample - loss: 0.0209 - accuracy: 0.7000 - mape: 68.5063 - mse: 0.0027
# Epoch 26/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0228 - accuracy: 0.7000 - mape: 70.0700 - mse: 0.0029
# Epoch 27/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0215 - accuracy: 0.7000 - mape: 73.5877 - mse: 0.0027
# Epoch 28/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0210 - accuracy: 0.7000 - mape: 72.2603 - mse: 0.0027
# Epoch 29/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0213 - accuracy: 0.7000 - mape: 70.6061 - mse: 0.0027
# Epoch 30/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0216 - accuracy: 0.7000 - mape: 69.1474 - mse: 0.0028
# Epoch 31/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0215 - accuracy: 0.7000 - mape: 70.5915 - mse: 0.0028
# Epoch 32/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0223 - accuracy: 0.7000 - mape: 72.1312 - mse: 0.0029
# Epoch 33/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0219 - accuracy: 0.7000 - mape: 67.8864 - mse: 0.0028
# Epoch 34/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0213 - accuracy: 0.7000 - mape: 65.7845 - mse: 0.0027
# Epoch 35/100
# 10/10 [==============================] - 0s 13ms/sample - loss: 0.0214 - accuracy: 0.7000 - mape: 72.7604 - mse: 0.0027
# 2022-08-31 16:01:17.859210: I tensorflow/core/profiler/lib/profiler_session.cc:184] Profiler session started.
# CPU times: user 1min, sys: 5.5 s, total: 1min 6s
# Wall time: 39.5 s

# %% [markdown]
# Comparing the predictions of the NN (neural network), the TL (transfer learning) and the ML (machine learning) model:

# %%
with open(f'../predictions/lstm/lstm_{CITY}_dengue_model_chik_predictions.pkl', 'rb') as f:
        data_nn = pickle.load(f)

doenca = 'dengue'
with open(f'../predictions/pgbm/pgbm_{CITY}_chik_cross_predictions.pkl', 'rb') as f:
        data_ml = pickle.load(f)

with open(f'../predictions/lstm/tl_{CITY}_transf_chik.pkl', 'rb') as f:
        data_tl = pickle.load(f) 
        

plt.figure()

plt.plot(data_nn['indice'][7:], data_nn['target'][:, -1] * data_nn['factor'] , color = 'black', label = 'data')

plt.plot(data_nn['indice'][7:],data_nn['pred'].iloc[:,-1] * data_nn['factor'], label = 'NN')

plt.plot(data_tl['indice'][7:],data_tl['pred'].iloc[:,-1] * data_tl['factor'], label = 'TL')

plt.plot(data_ml['dates'], data_ml['preds'], label = 'ML')

plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
from datetime import datetime
ini_index = data_nn['indice'].index(datetime.strptime(INI_EVALUATE, '%Y-%m-%d'))
end_index = data_nn['indice'].index(datetime.strptime(END_EVALUATE, '%Y-%m-%d'))

print('SS compared to NN:', ss( target = data_tl['target'][ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              forecast = data_tl['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              reference = data_nn['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_nn['factor']))
print('SS compared to ML:', ss( target = data_tl['target'][ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              forecast = data_tl['pred'].iloc[ini_index - 7: end_index - 7, -1] * data_tl['factor'],
                              reference = data_ml['preds'][ data_ml['dates'].index(datetime.strptime(INI_EVALUATE, '%Y-%m-%d')): data_ml['dates'].index(datetime.strptime(END_EVALUATE, '%Y-%m-%d'))] ))
# Out:
# SS compared to NN: 0.11569622018796744
# SS compared to ML: 0.23887497043128347
